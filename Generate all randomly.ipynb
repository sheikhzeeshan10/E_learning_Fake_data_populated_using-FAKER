# %%
from faker import Faker 
import pandas as pd 
import random
import datetime
from datetime import date
from sqlalchemy import create_engine
import sqlite3
from pydbgen import pydbgen
from datetime import datetime

# %%
def Platform(df):
    engine = create_engine('sqlite:///olearn.db', echo=True)
    sqlite_connection = engine.connect()

    sqlite_table = "Platform"
    df.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)

    sqlite_connection.close()
    print("Data for Plaform is  successfully Generated and Inserted!")
    

#creting main Platforms with necessary details just to make sure data generated should be meaningful
data = {'Platform_ID': ['IK01','IK02','IK03'],
        'Platform_Name': ['Coursera', 'Udemy', 'LinkedIn'],
        'Hyperlink_Path': ['https://www.coursera.org/', 'https://www.udemy.com/', 'https://www.linkedin.com/learning/']}
    
df = pd.DataFrame(data)
          




    

def courses(no_of_rows,d_now):
    fake = Faker()
    
    df = pd.DataFrame(([fake.profile() for i in range(no_of_rows)]))  #Generating Raw data 
    df["CourseID"] = df['sex'].astype(str)+ df["ssn"]         #generating course ID by slicing and mixing few columns
    df['CourseID'] =df.CourseID.str.slice(0, 10)       #only first time can generate unique course_id's upto 1000's       
    df2 = df['CourseID']
    df2 = df.iloc[:, [0]]                                      #taking job as Course_Name
    plt = []
    duration_ = []
    u = []
    tgs = []
    platform = ('IK01','IK02','IK03')
    dur = ('2h','4h 45m','6h 00m','3h 45m','5h 00m','4h 00m','45m', '1h')
    for i in range(len(df2.job)): 
        plt.append(random.choice(platform)) 
        duration_.append(random.choice(dur)) 
        tgs.append(fake.sentence())       
        u.append(fake.url())
    d = df2.assign(Course_ID=df['CourseID'], Platform_ID = plt, Duration = duration_,Creation_Date = d_now , Tags = tgs, Photo = u)
    df3 = d.rename(columns={'job': 'Course_Name'})         #renaming column
    save_db1(df3)
    
def save_db1(df3):
    engine = create_engine('sqlite:///olearn.db', echo=True)
    sqlite_connection = engine.connect()

    sqlite_table = "Course"
    df3.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)

    sqlite_connection.close()
    print("Data for courses is successfully Generated and Inserted!")





def users_table(no_of_rows):
    
    fake = Faker()
    ourDB= pydbgen.pydb()    
    df = pd.DataFrame(([fake.profile() for i in range(no_of_rows)]))
    df_new = df.iloc[:, [2,7]]    
    level = ('Beginner','Intermediate','Professional')    
    df_new.loc[:, ('ssn','username')]
    df_new = df_new.rename(columns={'ssn': 'Employer_Number','username':'Username'})    
    lvl= []
    pwd = []
    for i in range(len(df_new.Employer_Number)): 
        lvl.append(random.choice(level))
        pwd.append(fake.password())
    save_df = df_new.assign(Level= lvl,Creation_date=date.today(),Password = pwd)
    save_db2(save_df)


def save_db2(save_df):
    
    engine = create_engine('sqlite:///olearn.db', echo=True)
    sqlite_connection = engine.connect()
    
    sqlite_table = "Employers_Users"
    save_df.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)
    
    sqlite_connection.close()
    print("Data for users is successfully Generated and Inserted!")






def ongoing_training(no_of_rows):
    fake = Faker()
    df = pd.DataFrame(([fake.profile() for i in range(no_of_rows)]))  #Generating Raw data  
    df['job'] = df.job.str.slice(0, 4)
    df['ssn'] = df.ssn.str.slice(4, 10)
    df['Training_ID']= df['job'].astype(str)+ df['ssn']         #generating Training ID by slicing and mixing few columns     
    df = df.iloc[:, [13]]

    # Create a SQL connection to our SQLite database
    con = sqlite3.connect('olearn.db')
    cur = con.cursor()
    CourseID = []
    UserID = []

    for row in cur.execute('SELECT Course_ID FROM Course;'):
        CourseID.append(row)               #Fetching Course ID from User's tabel
    for row1 in cur.execute('SELECT User_ID FROM Employers_Users;'):
        UserID.append(row1)                #Fetching User ID from User's tabel

    CourseID = [item for t in CourseID for item in t]     #converting list of tuples into LIST
    UserID = [item for t in UserID for item in t]        #converting list of tuples into LIST

    status = ('Completed','Pending')
    completion_per = ('9%','60%','87%','30%','22%','3%','100%','60%')
    start_date = []
    comp_date  = []
    last_up = []
    userid_rand = []
    course_rand = []
    comp_per_rand = []
    status_rand = []

    for i in range(no_of_rows):
        start_date.append(fake.date_between_dates(date_start=datetime(2016,1,1), date_end=datetime(2018,12,31)))
        comp_date.append(fake.date_between_dates(date_start=datetime(2019,5,1), date_end=datetime(2021,12,31)))
        last_up.append(fake.date_between_dates(date_start=datetime(2021,12,31), date_end='now'))
        userid_rand.append(random.choice(UserID)) 
        course_rand.append(random.choice(CourseID))
        comp_per_rand.append(random.choice(completion_per))
        status_rand.append(random.choice(status))

    final_df = df.assign(User_ID = userid_rand, Course_ID = course_rand, Status = status_rand , 
    Completion_Percentage = comp_per_rand, Start_Date = start_date, Finish_Date = comp_date, Last_Update = last_up)
    save_db3(final_df)

def save_db3(final_df): 
    engine = create_engine('sqlite:///olearn.db', echo=True)
    sqlite_connection = engine.connect()

    sqlite_table = "Ongoing_Training"
    final_df.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)

    sqlite_connection.close()
    print("Ongoing Training Data successfully Generated and Inserted!")    
    






def certificates(no_of_rows):
    fake = Faker()
    df = pd.DataFrame(([fake.profile() for i in range(no_of_rows)]))  #Generating Raw data  
    df['job'] = df.job.str.slice(0, 2)
    df['ssn'] = df.ssn.str.slice(3, 10)
    df['Certification_ID']= df['job'].astype(str)+ df['ssn']         #generating Training ID by slicing and mixing few columns     
    df = df.iloc[:, [13]]

    # Create a SQL connection to our SQLite database
    con = sqlite3.connect('olearn.db')
    cur = con.cursor()
    CourseID = []
    UserID = []


    for row in cur.execute('SELECT Course_ID FROM Course;'):
        CourseID.append(row)               #Fetching Course ID from User's tabel
    for row1 in cur.execute('SELECT User_ID FROM Employers_Users;'):
        UserID.append(row1)                #Fetching User ID from User's tabel  

    CourseID = [item for t in CourseID for item in t]     #converting list of tuples into LIST
    UserID = [item for t in UserID for item in t]        #converting list of tuples into LIST

    completion_dur = ('400days','610days','365days','589days','458days','301days','629days','702das')
    comp_date  = []       
    userid_rand = []
    course_rand = []
    comp_dur_rand = []


    for i in range(no_of_rows):
        comp_date.append(fake.date_between_dates(date_start=datetime(2021,12,31), date_end='now'))
        userid_rand.append(random.choice(UserID)) 
        course_rand.append(random.choice(CourseID))
        comp_dur_rand.append(random.choice(completion_dur))

    final_df_ = df.assign(User_ID = userid_rand, Course_ID = course_rand, Completion_Duration = comp_dur_rand, 
    Completion_Date = comp_date)
    save_db4(final_df_)


def save_db4(final_df_):

    engine = create_engine('sqlite:///olearn.db', echo=True)
    sqlite_connection = engine.connect()

    sqlite_table = "certification_ID"
    final_df_.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)

    sqlite_connection.close()
    print("Certification Data successfully Generated and Inserted!")    

    
#no_of_rows = input('Enter number of rows to be generated:')
#certificates(int(no_of_rows))




def Reviews(no_of_rows):     
    fake = Faker()

    # Create a SQL connection to our SQLite database
    con = sqlite3.connect('olearn.db')
    cur = con.cursor()
    CourseID = []
    UserID = []


    for row in cur.execute('SELECT Course_ID FROM Course;'):
        CourseID.append(row)               #Fetching Course ID from User's tabel
    for row1 in cur.execute('SELECT User_ID FROM Employers_Users;'):
        UserID.append(row1)                #Fetching User ID from User's tabel  
    con.close()
    CourseID = [item for t in CourseID for item in t]     #converting list of tuples into LIST
    UserID = [item for t in UserID for item in t]        #converting list of tuples into LIST

    feedbk = ('Satisfied','Very Satisfied','Somehow Satisfied','Needs Improvement!','Obsolete!')

    ranking = ('1','2','3','4','5')

    userid_rand = []
    course_rand = []
    feedbk_rand = []
    ranking_rand = []
    inp_feedbk = []

    for i in range(no_of_rows):

        userid_rand.append(random.choice(UserID)) 
        course_rand.append(random.choice(CourseID))
        inp_feedbk = random.choice(feedbk)
        feedbk_rand.append(inp_feedbk)    
        #ranking_rand.append(random.choice(ranking))
        if inp_feedbk == 'Obsolete!':
            ranking_rand.append('1')
        elif inp_feedbk == 'Needs Improvement!':
            ranking_rand.append('2')
        elif inp_feedbk == 'Somehow Satisfied':
            ranking_rand.append('3')
        elif inp_feedbk == 'Satisfied':
            ranking_rand.append('4')
        else: #random.choice(feedbk) == 'Very Satisfied':
            ranking_rand.append('5')
    #print(ranking_rand)
    df = pd.DataFrame()
    final_dff = df.assign(User_ID = userid_rand, Course_ID = course_rand, Feedback = feedbk_rand, 
    Ranking_Score = ranking_rand)
    db_save_5(final_dff)

    
def db_save_5(final_dff):
    engine = create_engine('sqlite:///olearn.db', echo=True)
    sqlite_connection = engine.connect()

    sqlite_table = "Review"
    final_dff.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)

    sqlite_connection.close()
    print("Reviews Data successfully Generated and Inserted!")    

    





def main():
    x = input('Enter number of rows to be generated:')
    courses(int(x),date.today())
    users_table(int(x))
    ongoing_training(int(x))
    certificates(int(x))
    Reviews(int(x))

if __name__=="__main__":
    main()
# Out:
# Enter number of rows to be generated:5
# 2022-08-04 15:36:06,577 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Course")
# 2022-08-04 15:36:06,577 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-08-04 15:36:06,579 INFO sqlalchemy.engine.Engine INSERT INTO "Course" ("Course_Name", "Course_ID", "Platform_ID", "Duration", "Creation_Date", "Tags", "Photo") VALUES (?, ?, ?, ?, ?, ?, ?)
# 2022-08-04 15:36:06,579 INFO sqlalchemy.engine.Engine [generated in 0.00047s] (('Engineer, production', 'M153-15-75', 'IK02', '4h 45m', '2022-08-04', 'Sell six drive box car.', 'http://www.bond.com/'), ('Hospital doctor', 'M388-49-33', 'IK03', '4h 00m', '2022-08-04', 'Tell least season edge.', 'https://thompson-hayes.com/'), ('Advertising account executive', 'F337-52-68', 'IK01', '5h 00m', '2022-08-04', 'Like put side if draw smile.', 'http://fisher.info/'), ('Youth worker', 'M032-94-42', 'IK03', '5h 00m', '2022-08-04', 'Particularly church few charge six figure.', 'http://www.smith.net/'), ('Designer, blown glass/stained glass', 'M266-26-00', 'IK01', '4h 45m', '2022-08-04', 'Trade cover Congress little.', 'http://www.george-wilson.com/'))
# 2022-08-04 15:36:06,580 INFO sqlalchemy.engine.Engine COMMIT
# 2022-08-04 15:36:06,592 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-08-04 15:36:06,592 INFO sqlalchemy.engine.Engine [raw sql] ()
# Data for courses is successfully Generated and Inserted!
# 2022-08-04 15:36:06,614 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Employers_Users")
# 2022-08-04 15:36:06,615 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-08-04 15:36:06,616 INFO sqlalchemy.engine.Engine INSERT INTO "Employers_Users" ("Employer_Number", "Username", "Level", "Creation_date", "Password") VALUES (?, ?, ?, ?, ?)
# 2022-08-04 15:36:06,617 INFO sqlalchemy.engine.Engine [generated in 0.00039s] (('733-80-8969', 'nwalsh', 'Beginner', '2022-08-04', 'S0XOzsnL!9'), ('077-21-6459', 'srobbins', 'Beginner', '2022-08-04', 'EF0CmYBej%'), ('259-93-5946', 'ksilva', 'Professional', '2022-08-04', '!Z5EbRRefO'), ('632-93-0714', 'billhill', 'Intermediate', '2022-08-04', '0sQ%JmJ%(s'), ('485-16-6588', 'michelle38', 'Beginner', '2022-08-04', '!4+@PFu#uw'))
# 2022-08-04 15:36:06,617 INFO sqlalchemy.engine.Engine COMMIT
# 2022-08-04 15:36:06,619 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-08-04 15:36:06,619 INFO sqlalchemy.engine.Engine [raw sql] ()
# Data for users is successfully Generated and Inserted!
# 2022-08-04 15:36:06,638 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Ongoing_Training")
# 2022-08-04 15:36:06,639 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-08-04 15:36:06,641 INFO sqlalchemy.engine.Engine INSERT INTO "Ongoing_Training" ("Training_ID", "User_ID", "Course_ID", "Status", "Completion_Percentage", "Start_Date", "Finish_Date", "Last_Update") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2022-08-04 15:36:06,641 INFO sqlalchemy.engine.Engine [generated in 0.00095s] (('Engi76-587', 13616, 'M314-59-86', 'Completed', '60%', '2017-02-04', '2021-09-30', '2022-01-13'), ('Illu13-908', 13570, 'M117-24-02', 'Completed', '30%', '2017-07-14', '2021-08-26', '2022-05-30'), ('Medi15-211', 13623, 'M366-70-34', 'Pending', '60%', '2017-04-07', '2021-01-28', '2022-02-19'), ('Soft61-766', 13574, 'F523-85-29', 'Pending', '87%', '2017-01-28', '2020-11-05', '2022-06-21'), ('Air 82-589', 13556, 'F354-38-48', 'Completed', '60%', '2017-10-08', '2021-04-16', '2022-05-15'))
# 2022-08-04 15:36:06,642 INFO sqlalchemy.engine.Engine COMMIT
# 2022-08-04 15:36:06,644 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-08-04 15:36:06,645 INFO sqlalchemy.engine.Engine [raw sql] ()
# Ongoing Training Data successfully Generated and Inserted!
# 2022-08-04 15:36:06,663 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("certification_ID")
# 2022-08-04 15:36:06,663 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-08-04 15:36:06,665 INFO sqlalchemy.engine.Engine INSERT INTO "certification_ID" ("Certification_ID", "User_ID", "Course_ID", "Completion_Duration", "Completion_Date") VALUES (?, ?, ?, ?, ?)
# 2022-08-04 15:36:06,665 INFO sqlalchemy.engine.Engine [generated in 0.00053s] (('Re-20-839', 13625, 'M423-08-52', '301days', '2022-04-22'), ('Mu-08-451', 13568, 'F289-67-59', '458days', '2022-03-05'), ('Te-22-066', 13566, 'M886-46-74', '629days', '2022-04-27'), ('Re-68-255', 13582, 'F057-62-26', '610days', '2022-01-10'), ('Te-23-516', 13615, 'F160-71-16', '610days', '2022-01-10'))
# 2022-08-04 15:36:06,666 INFO sqlalchemy.engine.Engine COMMIT
# 2022-08-04 15:36:06,668 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-08-04 15:36:06,668 INFO sqlalchemy.engine.Engine [raw sql] ()
# Certification Data successfully Generated and Inserted!
# 2022-08-04 15:36:06,682 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Review")
# 2022-08-04 15:36:06,683 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-08-04 15:36:06,684 INFO sqlalchemy.engine.Engine INSERT INTO "Review" ("User_ID", "Course_ID", "Feedback", "Ranking_Score") VALUES (?, ?, ?, ?)
# 2022-08-04 15:36:06,684 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ((13620, 'F342-59-77', 'Needs Improvement!', '2'), (13625, 'F012-07-87', 'Obsolete!', '1'), (13555, 'M014-39-07', 'Somehow Satisfied', '3'), (13604, 'M073-63-02', 'Somehow Satisfied', '3'), (13620, 'M142-73-67', 'Satisfied', '4'))
# 2022-08-04 15:36:06,685 INFO sqlalchemy.engine.Engine COMMIT
# 2022-08-04 15:36:06,687 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-08-04 15:36:06,688 INFO sqlalchemy.engine.Engine [raw sql] ()
# Reviews Data successfully Generated and Inserted!
